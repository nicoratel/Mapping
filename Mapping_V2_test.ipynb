# %%
# %matplotlib widget
from Mapping_V2 import Mapping, BatchAzimProfileExtraction
import numpy as np
import glob
import os
# Out:
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl

# %% [markdown]
# # Extraction des profils azimutahux:
#
# Remarque:
#
# L'utilisation du Mapping contraint à avoir des valeurs de $\beta$ comprises entre 0 et 180°. On ne peut pas avoir accès au profil azimuthal complet, bien qu'il existe (en réalité il en manque une partie, mais on peut avoir le pic centré sur $\beta=0 ou 180°$ si on arrive à extraire le profil azimuthal sour toute la plage accessible).
#
# Afin d'y remédier, les profils azimuthaux SAXS et USAXS ont été extraits avec pyFAI (integrate_radial). Les corrections apportées par la projection des data dans l'espace réciproque sont négligeables aux petits et très petits angles, ce qui rend cette approche légitime.
#
# Dans ce qui suit, seuls les profils WAXS ont été extraits après projection des données dans l'espace réciproque. La comparaison des 2 méthodes (pyFAI et mapping) dans les domaines SAXS et USAXS donne des résultats très similaires (non présentés ici)

# %% [markdown]
# ## Co12 Data SAXS

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/Co12mes/'
maskpath='/home-local/ratel-ra/Bureau/ESRF_DATA/'
saxs_maskfile=maskpath+'mask-1m4_eiger2.edf'
batch=BatchAzimProfileExtraction(path=path,binning=2,instrument='ID02',threshold=0.02,qvalues=[0.1,0.173],file_filter='LPCNOsaxs_eiger2*.h5')
batch.plot_save_azim_profiles_vs_B(prefix='SAXS_pyFAI',method='pyFAI')
batch.fit_azimprofiles(plot=True,r2_threshold=0.75,prefix='SAXS_pyFAI',method='pyFAI')

# %% [markdown]
# ## Co12 data USAXS

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/Co12mes/'
batch=BatchAzimProfileExtraction(path=path,binning=2,instrument='ID02',threshold=0.02,qvalues=[0.005,0.01],file_filter='LPCNO_eiger2*.h5')
batch.plot_save_azim_profiles_vs_B(prefix='USAXS_pyFAI',method='pyFAI')
batch.fit_azimprofiles(plot=True,r2_threshold=0.75,prefix='USAXS_pyFAI',method='pyFAI')

# %% [markdown]
# ## Co12 data waxs

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/Co12mes/'
reflections=[[1,0,0],[0,0,2],[1,0,1]]
cif_file='/home-local/ratel-ra/Bureau/ESRF_DATA/Co_P63mmc.cif'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='ID02',cif=cif_file,reflections=reflections,file_filter='*_waxs*.h5',threshold=0.0001)
batch.plot_save_azim_profiles_vs_B(prefix='WAXS')
batch.fit_azimprofiles(plot=True,r2_threshold=0.75,prefix='WAXS')
# Out:
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#                       File Name      Sample_name  B (mT)        hkl  \
# 0   LPCNOsaxs_waxs_00376_raw.h5  Co12-mes2_fresh     100  (1, 0, 0)
# 1   LPCNOsaxs_waxs_00376_raw.h5  Co12-mes2_fresh     100  (0, 0, 2)
# 2   LPCNOsaxs_waxs_00376_raw.h5  Co12-mes2_fresh     100  (1, 0, 1)
# 3   LPCNOsaxs_waxs_00377_raw.h5  Co12-mes2_fresh     200  (1, 0, 0)
# 4   LPCNOsaxs_waxs_00377_raw.h5  Co12-mes2_fresh     200  (0, 0, 2)
# 5   LPCNOsaxs_waxs_00377_raw.h5  Co12-mes2_fresh     200  (1, 0, 1)
# 6   LPCNOsaxs_waxs_00378_raw.h5  Co12-mes2_fresh     400  (1, 0, 0)
# 7   LPCNOsaxs_waxs_00378_raw.h5  Co12-mes2_fresh     400  (0, 0, 2)
# 8   LPCNOsaxs_waxs_00378_raw.h5  Co12-mes2_fresh     400  (1, 0, 1)
# 9   LPCNOsaxs_waxs_00379_raw.h5  Co12-mes2_fresh     600  (1, 0, 0)
# 10  LPCNOsaxs_waxs_00379_raw.h5  Co12-mes2_fresh     600  (0, 0, 2)
# 11  LPCNOsaxs_waxs_00379_raw.h5  Co12-mes2_fresh     600  (1, 0, 1)
# 12  LPCNOsaxs_waxs_00380_raw.h5  Co12-mes2_fresh     800  (1, 0, 0)
# 13  LPCNOsaxs_waxs_00380_raw.h5  Co12-mes2_fresh     800  (0, 0, 2)
# 14  LPCNOsaxs_waxs_00380_raw.h5  Co12-mes2_fresh     800  (1, 0, 1)
# 15  LPCNOsaxs_waxs_00381_raw.h5  Co12-mes2_fresh    1000  (1, 0, 0)
# 16  LPCNOsaxs_waxs_00381_raw.h5  Co12-mes2_fresh    1000  (0, 0, 2)
# 17  LPCNOsaxs_waxs_00381_raw.h5  Co12-mes2_fresh    1000  (1, 0, 1)
# 18  LPCNOsaxs_waxs_00382_raw.h5  Co12-mes2_fresh    1400  (1, 0, 0)
# 19  LPCNOsaxs_waxs_00382_raw.h5  Co12-mes2_fresh    1400  (0, 0, 2)
# 20  LPCNOsaxs_waxs_00382_raw.h5  Co12-mes2_fresh    1400  (1, 0, 1)
# 21  LPCNOsaxs_waxs_00383_raw.h5  Co12-mes2_fresh    1000  (1, 0, 0)
# 22  LPCNOsaxs_waxs_00383_raw.h5  Co12-mes2_fresh    1000  (0, 0, 2)
# 23  LPCNOsaxs_waxs_00383_raw.h5  Co12-mes2_fresh    1000  (1, 0, 1)
# 24  LPCNOsaxs_waxs_00384_raw.h5  Co12-mes2_fresh     400  (1, 0, 0)
# 25  LPCNOsaxs_waxs_00384_raw.h5  Co12-mes2_fresh     400  (0, 0, 2)
# 26  LPCNOsaxs_waxs_00384_raw.h5  Co12-mes2_fresh     400  (1, 0, 1)
# 27  LPCNOsaxs_waxs_00385_raw.h5  Co12-mes2_fresh     100  (1, 0, 0)
# 28  LPCNOsaxs_waxs_00385_raw.h5  Co12-mes2_fresh     100  (0, 0, 2)
# 29  LPCNOsaxs_waxs_00385_raw.h5  Co12-mes2_fresh     100  (1, 0, 1)
#
#       background             I  Gaussian peak position  Gaussian sigma  \
# 0   2.785746e+01    415.851153               89.317627       10.977084
# 1   6.617529e-15    552.833007              165.517408        5.197657
# 2   2.341216e+01    593.171551               61.420964        8.218912
# 3   3.029649e+01    681.881463               89.519492        7.586696
# 4   5.294400e-16    730.375720              165.517408        4.488926
# 5   6.126994e+01   1225.226736              118.166369        6.734113
# 6   2.868932e+01    585.810107               89.664223        4.984580
# 7   2.511905e+01    115.970865               14.486032        2.150388
# 8   5.645134e+01   1262.697995              118.161905        5.295799
# 9   2.956354e+01    732.594137               89.764991        3.951988
# 10  4.975194e+01    275.072723              122.862468        8.131907
# 11  6.565677e+01   1657.061717              118.053761        4.331162
# 12  3.228122e+01    700.382690               89.815051        3.581165
# 13  5.281355e+01    139.650194              112.651287        5.857904
# 14  7.408690e+01    844.452780              116.303856        2.090326
# 15  3.384312e+01    844.805746               89.814120        2.958105
# 16  3.769299e-23   4320.640995               90.551703       28.619439
# 17  5.439695e-59    125.027056               67.863090        1.080550
# 18  3.793421e+01    812.573729               89.826218        2.654992
# 19  3.003630e+02   2780.683462              100.849231       12.791564
# 20  1.325968e-07  16258.522414               96.618285       26.982446
# 21  3.354905e+01    825.656030               89.813390        2.708956
# 22  1.313806e+01   1105.550204               67.499312       42.941528
# 23  1.739931e-58    100.989725               67.914788        1.061820
# 24  3.212169e+01    908.337407               89.778731        2.878633
# 25  1.015589e+02  14975.202790              165.517408       49.912648
# 26  6.064313e+01   1919.733242              117.927705        2.898796
# 27  3.041327e+01    764.543664               89.700098        3.139709
# 28  4.911105e+01    112.725605              165.517408        5.254549
# 29  3.999066e+01   1551.829013              117.810742        3.072056
#
#     Background slope  Degree of Order S  R_squared
# 0          -0.006560           0.440572   0.961103
# 1           0.240763           0.217449   0.985395
# 2           0.150385           0.169768   0.974717
# 3          -0.003577           0.470345   0.976946
# 4           0.258249           0.219707   0.981200
# 5          -0.206598           0.162446   0.986298
# 6          -0.006140           0.486913   0.985303
# 7           0.031088           0.225058   0.950926
# 8          -0.249925           0.152975   0.971747
# 9          -0.006484           0.491731   0.990711
# 10         -0.253298           0.131968   0.902530
# 11         -0.359032           0.150565   0.985494
# 12         -0.047064           0.493203   0.978053
# 13         -0.297972           0.250321   0.869922
# 14         -0.445699           0.183673   0.894805
# 15         -0.006959           0.495344   0.997373
# 16         -0.312984           0.307967   0.757853
# 17          0.358873           0.265592   0.664305
# 18         -0.040035           0.496244   0.996156
# 19         -3.667229           0.377381   0.641647
# 20         -2.155101           0.311132   0.698410
# 21         -0.007595           0.496089   0.996847
# 22          0.083508           0.253354   0.138915
# 23          0.351794           0.266571   0.643507
# 24         -0.001911           0.495581   0.995767
# 25         -1.231898           0.144431   0.733633
# 26         -0.254325           0.150656   0.987908
# 27         -0.002143           0.494732   0.995978
# 28         -0.131393           0.217258   0.798206
# 29         -0.067095           0.153050   0.996615

# %% [markdown]
# # Echantillon Organométallique JNC21/JNC108

# %% [markdown]
# ## JNC 21 data SAXS
#
# Remplacé par JNC108 data SAXS (manip non viable car nanobâtonnets déjà alignés)

# %% [markdown]
# ## JNC21 data USAXS

# %%
# %matplotlib widget
from Mapping_V2 import Mapping, BatchAzimProfileExtraction
import numpy as np
import glob
import os

path='/home-local/ratel-ra/Bureau/ESRF_DATA/JNC21/'
batch=BatchAzimProfileExtraction(path=path,binning=2,instrument='ID02',threshold=0.02,qvalues=[0.005,0.01],file_filter='Co*_eiger2*.h5')
#batch.plot_save_azim_profiles_vs_B(prefix='USAXS_pyFAI',method='pyFAI')
batch.fit_azimprofiles(plot=True,r2_threshold=0.75,prefix='USAXS_pyFAI',method='pyFAI')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#                            File Name Sample_name  B (mT)  qvalue  background  \
# 0  CobaltNanoRod_eiger2_00003_raw.h5       JNC21     100   0.005    2.719860
# 1  CobaltNanoRod_eiger2_00003_raw.h5       JNC21     100   0.010    0.215111
# 2  CobaltNanoRod_eiger2_00005_raw.h5       JNC21     400   0.005    2.819542
# 3  CobaltNanoRod_eiger2_00005_raw.h5       JNC21     400   0.010    0.472253
# 4  CobaltNanoRod_eiger2_00007_raw.h5       JNC21    1000   0.005    1.338998
# 5  CobaltNanoRod_eiger2_00007_raw.h5       JNC21    1000   0.010    0.164087
# 6  CobaltNanoRod_eiger2_00009_raw.h5       JNC21    1000   0.005   43.379809
# 7  CobaltNanoRod_eiger2_00009_raw.h5       JNC21    1000   0.010    0.458488
# 8  CobaltNanoRod_eiger2_00014_raw.h5       JNC21     100   0.005    8.599845
# 9  CobaltNanoRod_eiger2_00014_raw.h5       JNC21     100   0.010    0.573234
#
#              I  Gaussian peak position  Gaussian sigma  Background slope  \
# 0    46.167186               88.761808       13.005787         -0.001355
# 1     1.755708              114.392525        8.495415         -0.001149
# 2   116.372566               91.458189       13.910008          0.000982
# 3     4.140904               77.299274       16.436100          0.001392
# 4   187.478294               90.633374       17.014844          0.002664
# 5     4.303180              115.092107        9.290855         -0.003548
# 6  2381.171694               97.291379       21.191353         -0.305058
# 7    77.613118              115.127804        7.788000         -0.061717
# 8  3238.151759               93.749396       26.252813         -0.096281
# 9    61.859392              115.674279        8.123740         -0.050063
#
#    Degree of Order S  R_squared
# 0           0.419594   0.719319
# 1           0.226022   0.269597
# 2           0.410053   0.905413
# 3           0.342491   0.391023
# 4           0.379915   0.953172
# 5           0.220121   0.633592
# 6           0.337640   0.899444
# 7           0.212564   0.890710
# 8           0.316507   0.916119
# 9           0.206251   0.871924

# %% [markdown]
# ## JNC 21 data WAXS

# %%
path='/home-local/ratel-ra/Bureau/ESRF_DATA/JNC21/'
reflections=[[1,0,0],[0,0,2],[1,0,1]]
cif_file='/home-local/ratel-ra/Bureau/ESRF_DATA/Co_P63mmc.cif'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='ID02',cif=cif_file,reflections=reflections,file_filter='*_waxs*.h5',threshold=0.0001)
#batch.plot_save_azim_profiles_vs_B(prefix='WAXS')
batch.fit_azimprofiles(plot=True,r2_threshold=0.75,prefix='WAXS')
# Out:
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Crystal structure loaded from CIF:
# Lattice parameters: a=2.5071, b=2.5071, c=4.068600, alpha=90, beta=90, gamma=120
# Atom Co: [0.33333 0.66667 0.25   ]
# Atom Co: [0.66667 0.33334 0.75   ]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#                           File Name Sample_name  B (mT)        hkl  \
# 0   CobaltNanoRod_waxs_00003_raw.h5       JNC21     100  (1, 0, 0)
# 1   CobaltNanoRod_waxs_00003_raw.h5       JNC21     100  (0, 0, 2)
# 2   CobaltNanoRod_waxs_00003_raw.h5       JNC21     100  (1, 0, 1)
# 3   CobaltNanoRod_waxs_00005_raw.h5       JNC21     400  (1, 0, 0)
# 4   CobaltNanoRod_waxs_00005_raw.h5       JNC21     400  (0, 0, 2)
# 5   CobaltNanoRod_waxs_00005_raw.h5       JNC21     400  (1, 0, 1)
# 6   CobaltNanoRod_waxs_00007_raw.h5       JNC21    1000  (1, 0, 0)
# 7   CobaltNanoRod_waxs_00007_raw.h5       JNC21    1000  (0, 0, 2)
# 8   CobaltNanoRod_waxs_00007_raw.h5       JNC21    1000  (1, 0, 1)
# 9   CobaltNanoRod_waxs_00009_raw.h5       JNC21    1000  (1, 0, 0)
# 10  CobaltNanoRod_waxs_00009_raw.h5       JNC21    1000  (0, 0, 2)
# 11  CobaltNanoRod_waxs_00009_raw.h5       JNC21    1000  (1, 0, 1)
# 12  CobaltNanoRod_waxs_00014_raw.h5       JNC21     100  (1, 0, 0)
# 13  CobaltNanoRod_waxs_00014_raw.h5       JNC21     100  (0, 0, 2)
# 14  CobaltNanoRod_waxs_00014_raw.h5       JNC21     100  (1, 0, 1)
#
#       background            I  Gaussian peak position  Gaussian sigma  \
# 0   1.136816e+01     2.557601              156.194274        0.831310
# 1   1.171729e+01   115.228396               88.872892       13.076167
# 2   1.369394e+01   653.383961              157.081055       55.954722
# 3   1.096678e+01     3.454924              136.943279        1.724131
# 4   1.219756e+01   232.808638               89.497817        5.986850
# 5   2.114127e+01    92.980864              139.238869        9.576543
# 6   1.170340e+01    29.726735               89.440996        1.855227
# 7   1.178551e+01   139.722947               89.774482        2.517685
# 8   2.924328e+01   896.999505              113.880236       25.713704
# 9   2.651239e+01   531.425093               89.781627        2.062080
# 10  2.575853e+01    11.242614               89.790002        1.073593
# 11  2.850612e-25   377.522976               76.938301        9.649169
# 12  2.573572e+01   463.197487               89.502492        3.475145
# 13  2.418393e+01   150.107702              165.517408        2.882959
# 14  2.639000e+01  1110.628472              117.522448        3.112456
#
#     Background slope  Degree of Order S  R_squared
# 0           0.003712           0.304663   0.059271
# 1           0.003387           0.418973   0.581150
# 2          -0.035339           0.160305   0.055856
# 3           0.008887           0.204244   0.053446
# 4           0.004055           0.481212   0.925188
# 5          -0.072067           0.211657   0.719839
# 6           0.003164           0.498004   0.779746
# 7           0.000684           0.496608   0.963335
# 8          -0.290822           0.278230   0.187029
# 9           0.050532           0.497714   0.991086
# 10          0.046036           0.499363   0.314925
# 11          0.180746           0.377227   0.746522
# 12          0.040735           0.493484   0.978204
# 13          0.052827           0.223742   0.903307
# 14          0.016877           0.158819   0.993058

# %% [markdown]
# # Echantillon JNC108 _ Data SAXS LGC - pyFAI

# %%
# %matplotlib widget
from Mapping_V2 import Mapping, BatchAzimProfileExtraction


path='/home-local/ratel-ra/Bureau/ESRF_DATA/JNC108/'
batch=BatchAzimProfileExtraction(path=path,binning=1,instrument='LGC',threshold=0.05,qvalues=[0.1,0.173],file_filter='JNC108*.edf')
#batch.plot_save_azim_profiles_vs_B(prefix='SAXS_pyFAI',method='pyFAI')
batch.fit_azimprofiles(plot=True,r2_threshold=0.75,prefix='SAXS_pyFAI', method='pyFAI')
# Out:
# /home-local/ratel-ra/Documents/SAXS_data/SAXS_ESRF/HC-5495/code_profil_azimuthal_waxs/docs_marianne/Mapping_V2.py:322: RuntimeWarning: invalid value encountered in scalar divide
#   self.thetaB[j,i] = np.arcsin(self.q_parr[j,i] / self.norm_Q[j,i]) * 180 / np.pi  # in degrees
# /home-local/ratel-ra/Documents/SAXS_data/SAXS_ESRF/HC-5495/code_profil_azimuthal_waxs/docs_marianne/Mapping_V2.py:323: RuntimeWarning: invalid value encountered in scalar divide
#   self.beta[j,i] = np.arccos(self.q_parr[j,i] / self.norm_Q[j,i]) * 180 / np.pi  # in degrees
# /home-local/ratel-ra/anaconda3_c/envs/py311/lib/python3.11/site-packages/pyFAI/azimuthalIntegrator.py:1670: RuntimeWarning: invalid value encountered in divide
#   intensity = sum_signal / sum_normalization
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#                                File Name    Sample_name  B (mT)  qvalue  \
# 0        JNC108_Averaged_Img_016-020.edf         JNC108       0   0.100
# 1        JNC108_Averaged_Img_016-020.edf         JNC108       0   0.173
# 2  JNC108_100mT_Averaged_Img_022-026.edf  JNC108 @100mT     100   0.100
# 3  JNC108_100mT_Averaged_Img_022-026.edf  JNC108 @100mT     100   0.173
# 4  JNC108_400mT_Averaged_Img_028-032.edf  JNC108 @400mT     400   0.100
# 5  JNC108_400mT_Averaged_Img_028-032.edf  JNC108 @400mT     400   0.173
# 6  JNC108_800mT_Averaged_Img_034-038.edf  JNC108 @800mT     800   0.100
# 7  JNC108_800mT_Averaged_Img_034-038.edf  JNC108 @800mT     800   0.173
#
#      background           I  Gaussian peak position  Gaussian sigma  \
# 0  8.889444e-12  206.461810              121.090722       50.011731
# 1  5.623579e-02    3.770423              172.103352        9.115851
# 2  9.647503e-13  254.683616              168.816461       20.465386
# 3  5.607984e-02    3.704008              172.104053        8.974191
# 4  4.227021e-14  992.202942              179.590333       30.725873
# 5  3.271441e-21    0.188061                3.345155        2.285644
# 6  2.096436e+00   80.180897               90.890129        3.356347
# 7  8.643072e-02    2.117809                5.309317        9.043409
#
#    Background slope  Degree of Order S  R_squared
# 0         -0.015533           0.228646   0.563937
# 1         -0.000438           0.133660   0.920747
# 2         -0.008174           0.147656   0.891852
# 3         -0.000435           0.133507   0.935542
# 4         -0.036011           0.102975   0.904854
# 5         -0.000756           0.058859   0.892305
# 6         -0.002098           0.493623   0.994514
# 7         -0.002128           0.106238   0.904939
